# %% [markdown]
# <a href="https://colab.research.google.com/github/dldustj0715/machine_learning/blob/main/%EA%B8%B0%EA%B3%84%ED%95%99%EC%8A%B5_diabetes_BMI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# 상관 관계 행렬
df_corr = df.corr()

# 히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# ## 입력 데이터(X)와 target(y) 설정
#
# - 예측할 값: `BMI`
# - 기존 classification 정답인 `Outcome`은 입력 변수에서 제외합니다.

# %%
X = df.drop(['BMI', 'Outcome'], axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y = df['BMI']
y.head()
# Out:
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# Name: BMI, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=True,
    random_state=12
)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (614, 7) (614,)
# (154, 7) (154,)

# %% [markdown]
# ## 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

ly_preds = model.predict(X_test)

mse = mean_squared_error(y_test, ly_preds)
rmse = np.sqrt(mse)

print("평균제곱오차(MSE):", mse)
print("평균제곱근오차(RMSE):", rmse)
# Out:
# 평균제곱오차(MSE): 51.578866344300216
# 평균제곱근오차(RMSE): 7.181842823697844

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Glucose'], y_test, label='y_test')
plt.scatter(X_test['Glucose'], ly_preds, c='y', label='ly_preds')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

dy_preds = model.predict(X_test)

mse = mean_squared_error(y_test, dy_preds)
rmse = np.sqrt(mse)

print("평균제곱오차(MSE):", mse)
print("평균제곱근오차(RMSE):", rmse)
# Out:
# 평균제곱오차(MSE): 78.2561038961039
# 평균제곱근오차(RMSE): 8.846248012355515

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Glucose'], y_test, label='y_test')
plt.scatter(X_test['Glucose'], dy_preds, c='g', label='dy_preds')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

ry_preds = model.predict(X_test)

mse = mean_squared_error(y_test, ry_preds)
rmse = np.sqrt(mse)

print("평균제곱오차(MSE):", mse)
print("평균제곱근오차(RMSE):", rmse)
# Out:
# 평균제곱오차(MSE): 43.65067656493505
# 평균제곱근오차(RMSE): 6.606865865517102

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Glucose'], y_test, label='y_test')
plt.scatter(X_test['Glucose'], ry_preds, c='orange', label='ry_preds')
plt.legend()
plt.show()

# %% [markdown]
# ## 4. SVR

# %%
from sklearn.svm import SVR

model = SVR(kernel='linear')
model.fit(X_train, y_train)

sy_preds = model.predict(X_test)

mse = mean_squared_error(y_test, sy_preds)
rmse = np.sqrt(mse)

print("평균제곱오차(MSE):", mse)
print("평균제곱근오차(RMSE):", rmse)
# Out:
# 평균제곱오차(MSE): 49.07251213408428
# 평균제곱근오차(RMSE): 7.005177523381136

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Glucose'], y_test, label='y_test')
plt.scatter(X_test['Glucose'], sy_preds, c='orange', label='sy_preds')
plt.legend()
plt.show()
